# %%
# !pip install unidecode
# Out:
# Collecting unidecode
#   Downloading https://files.pythonhosted.org/packages/31/39/53096f9217b057cb049fe872b7fc7ce799a1a89b76cf917d9639e7a558b5/Unidecode-1.0.23-py2.py3-none-any.whl (237kB)
#      |████████████████████████████████| 245kB 8.4MB/s
# Installing collected packages: unidecode
# Successfully installed unidecode-1.0.23

# %%
# https://github.com/spro/char-rnn.pytorch

import unidecode
import string
import random
import time
import math
import torch
from torch.autograd import Variable

USE_CUDA = True

# Reading and un-unicode-encoding data

all_characters = string.printable
n_characters = len(all_characters)
SOS = n_characters
EOS = n_characters + 1
n_characters += 2

def read_file(filename):
    file = unidecode.unidecode(open(filename).read())
    return file, len(file)

# Turning a string into a tensor

def char_tensor(string):
    size = len(string) + 1
    tensor = torch.zeros(size).long()
    for c in range(len(string)):
        tensor[c] = all_characters.index(string[c])
    tensor[-1] = EOS
    tensor = Variable(tensor)
    if USE_CUDA:
        tensor = tensor.cuda()
    return tensor

# Turn a tensor into a string

def index_to_char(top_i):
    if top_i == EOS:
        return '$'
    elif top_i == SOS:
        return '^'
    else:
        return all_characters[top_i]

def tensor_to_string(t):
    s = ''
    for i in range(t.size(0)):
        ti = t[i]
        top_k = ti.data.topk(1)
        top_i = top_k[1][0]
        s += index_to_char(top_i)
        if top_i == EOS: break
    return s

def longtensor_to_string(t):
    s = ''
    for i in range(t.size(0)):
        top_i = t.data[i]
        s += index_to_char(top_i)
    return s

# Readable time elapsed

def time_since(since):
    s = time.time() - since
    m = math.floor(s / 60)
    s -= m * 60
    return '%dm %ds' % (m, s)

# %% [markdown]
# #MODEL

# %%
#https://github.com/spro/pytorch-text-vae
import torch
import torch.nn as nn
from torch.autograd import variable
import torch.nn.functional as F

MIN_LENGTH = 10
MAX_LENGTH = 50
MAX_SAMPLE = False
MAX_SAMPLE = True

# %%
class Encoder(nn.Module):
  
    def sample(self, mu, logvar):
      
        eps = Variable(torch.randn(mu.size()))
        
        if USE_CUDA:
          
            eps = eps.cuda()
         
        std = torch.exp(logvar / 2.0)
        
        return mu + eps * std

# %%
class EncoderRNN(Encoder):
    
    def __init__(self, input_size, hidden_size, output_size, n_layers = 1, bidirectional = True):
        
        super(EncoderRNN, self).__init__()
        
        self.input_size = input_size
        
        self.hidden_size = hidden_size
        
        self.output_size = output_size
        
        self.n_layers = n_layers
        
        self.bidirectional = bidirectional
        
        self.embed = nn.Embedding(input_size, hidden_size)
        self.gru = nn.GRU(hidden_size, hidden_size, n_layers, dropout = 0.1, bidirectional = bidirectional)
        self.o2p = nn.Linear(hidden_size, output_size*2)
        
    
    def forward(self, input):
        embedded = self.embed(input).unsqueeze(1)

        output, hidden = self.gru(embedded, None)
        output = output[-1] # Take only the last value
        if self.bidirectional:
            output = output[:, :self.hidden_size] + output[: ,self.hidden_size:] # Sum bidirectional outputs

        ps = self.o2p(output)
        mu, logvar = torch.chunk(ps, 2, dim=1)
        z = self.sample(mu, logvar)
        
        return mu, logvar, z

# %%
class DecoderRNN(nn.Module):
    
    def __init__(self, input_size, hidden_size, output_size, n_layers = 1, dropout_p = 0.1):
        super(DecoderRNN, self).__init__()
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.n_layers = n_layers
        
        self.embed = nn.Embedding(output_size, hidden_size)
        self.dropout = nn.Dropout(dropout_p)
        self.z2h = nn.Linear(input_size, hidden_size)
        self.gru = nn.GRU(hidden_size + input_size, hidden_size, n_layers, dropout = dropout_p)
        self.i2h = nn.Linear(hidden_size + input_size, hidden_size)
        self.h2o = nn.Linear(hidden_size*2, hidden_size)
        self.out = nn.Linear(hidden_size + input_size, output_size)
        
        
    def sample(self, output, temperature):
        if MAX_SAMPLE:
            
            top_i = output.data.topk(1)[1][0][0]
        
        else:
            
            output_dist = output.data.view(-1).div(temperature).exp()
            top_i = torch.multinomial(output_dist, 1)[0]
        
        input = Variable(torch.LongTensor([top_i]))
        if USE_CUDA:
            input = input.cuda()
        
        return input, top_i
    
    def forward(self, z, inputs, temperature):
        n_steps = inputs.size(0)
        outputs = Variable(torch.zeros(n_steps, 1, self.output_size))
        if USE_CUDA:
            outputs = outputs.cuda()
        
        input = Variable(torch.LongTensor([SOS]))
        if USE_CUDA:
            input = input.cuda()
        
        hidden = self.z2h(z).unsqueeze(0).repeat(self.n_layers, 1, 1)
        
        for i in range(n_steps):
            output, hidden = self.step(i, z, input, hidden, temperature)
            outputs[i] = output
            
            use_teacher_forcing = random.random() < temperature
            
            if use_teacher_forcing:
                input = inputs[i]
            
            else:
                input, top_i = self.sample(output, temperature)
            
            
        
        
        return outputs.squeeze(1)
     
    def generate(self, z, n_steps, temperature):
        outputs = Variable(torch.zeros(n_steps, 1, self.output_size))
        
        if USE_CUDA:
            ouputs = outputs.cuda()
        
        input = Variable(torch.LongTensor([SOS]))
        
        if USE_CUDA:
            input = input.cuda()
        hidden = self.z2h(z).unsqueeze(0).repeat(self.n_layers, 1, 1)
        
        for i in range(n_steps):
            output, hidden = self.step(i, z, input, hidden, temperature)
            outputs[i] = output
            input, top_i = self.sample(output, temperature)
            if top_i == EOS: break
        
        return outputs.squeeze(1)
   
  
  
  
    def step(self, s, z, input, hidden, temperature = 0.3):
        
        input = F.relu(self.embed(input))
        input = input.squeeze(0) #added manually 
        input = input.unsqueeze(0) #added manually
#         print(input.size())
#         print('Hi')
#         print(z.size())
        input = torch.cat((input, z), 1)
        input = input.unsqueeze(0)
        output, hidden = self.gru(input, hidden)
        output = output.squeeze(0)
        output = torch.cat((output, z), 1)
        output = self.out(output)
        return output, hidden

# %%
class VAE(nn.Module):
    
    def __init__(self, encoder, decoder):
        super(VAE, self).__init__()
        self.encoder = encoder
        self.decoder = decoder
        
   
    def forward(self, inputs, temperature = 1.0):
        m, l, z = self.encoder(inputs)
        decoded = self.decoder(z, inputs, temperature)
        return m, l, z, decoded

# %% [markdown]
# ###Testing the model

# %%
    hidden_size = 20
    embed_size = 10
    e = EncoderRNN(n_characters, hidden_size, embed_size)
    d = DecoderRNN(embed_size, hidden_size, n_characters, 2)
    if USE_CUDA:
        e.cuda()
        d.cuda()
    vae = VAE(e, d)
    m, l, z, decoded = vae(char_tensor('@spro'))
    print('m =', m.size())
    print('l =', l.size())
    print('z =', z.size())
    print('decoded', tensor_to_string(decoded))
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/rnn.py:54: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   "num_layers={}".format(dropout, num_layers))
# m = torch.Size([1, 10])
# l = torch.Size([1, 10])
# z = torch.Size([1, 10])
# decoded HHHHll

# %% [markdown]
# #Train

# %%
# !pip install sconce
import sconce
# Out:
# Collecting sconce
#   Downloading https://files.pythonhosted.org/packages/41/fd/ccb2748edcc2956b287ded14401fff1ad36471f3fab242ae73c708e1f0ae/sconce-0.0.2-py2.py3-none-any.whl
# Installing collected packages: sconce
# Successfully installed sconce-0.0.2

# %%
import sconce
import sys


hidden_size = 500
embed_size = 50
learning_rate = 0.0001
n_epochs = 1000
grad_clip = 1.0

kld_start_inc = 10000
kld_weight = 0.05
kld_max = 0.1
kld_inc = 0.000002
temperature = 0.9
temperature_min = 0.5
temperature_dec = 0.000002

# %%
from google.colab import drive
drive.mount("/content/drive", force_remount=True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
file, file_len = read_file('drive/My Drive/Data/beatles.txt')

print(file_len)
# Out:
# 70685

# %%
lines = [line.strip() for line in file.split('\n')]
print(len(lines))
# Out:
# 1846

# %%
def good_size(line):
    return len(line) >= MIN_LENGTH and len(line) <= MAX_LENGTH

def good_content(line):
    return 'http' not in line and '/' not in line

# %%
lines = [line for line in lines if good_size(line) and good_content(line)]

# %%
print('n lines', len(lines))
# Out:
# n lines 1462

# %%
def random_training_set():
  line = random.choice(lines)
  inp  = char_tensor(line)
  target = char_tensor(line)
  return inp, target

# %%
e = EncoderRNN(n_characters, hidden_size, embed_size)
d = DecoderRNN(embed_size, hidden_size, n_characters, 2)
vae = VAE(e, d)
optimizer = torch.optim.Adam(vae.parameters(), lr=learning_rate)

criterion = nn.CrossEntropyLoss()

if USE_CUDA:
    vae.cuda()
    criterion.cuda()
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/rnn.py:54: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   "num_layers={}".format(dropout, num_layers))

# %%
log_every = 20
save_every = 500


def save():
    save_filename = 'vae.pt'
    torch.save(vae, save_filename)
    print('Saved as %s' % save_filename)

# %%
 for epoch in range(n_epochs):
        input, target = random_training_set()

        optimizer.zero_grad()

        m, l, z, decoded = vae(input, temperature)
        if temperature > temperature_min:
            temperature -= temperature_dec

        loss = criterion(decoded, target)
       # job.record(epoch, loss.data[0])

        KLD = (-0.5 * torch.sum(l - torch.pow(m, 2) - torch.exp(l) + 1, 1)).mean().squeeze()
        loss += KLD * kld_weight

        if epoch > kld_start_inc and kld_weight < kld_max:
            kld_weight += kld_inc

        loss.backward()
        # print('from', next(vae.parameters()).grad.data[0][0])
        ec = torch.nn.utils.clip_grad_norm(vae.parameters(), grad_clip)
        # print('to  ', next(vae.parameters()).grad.data[0][0])
        optimizer.step()

        if epoch % log_every == 0:
            print('[%d] %.4f (k=%.4f, t=%.4f, kl=%.4f, ec=%.4f)' % (
                epoch, loss.item(), kld_weight, temperature, KLD.item(), ec
            ))
            print('   (target) "%s"' % longtensor_to_string(target))
            generated = vae.decoder.generate(z, MAX_LENGTH, temperature)
            print('(generated) "%s"' % tensor_to_string(generated))
            print('')

        if epoch > 0 and epoch % save_every == 0:
            save()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:21: UserWarning: torch.nn.utils.clip_grad_norm is now deprecated in favor of torch.nn.utils.clip_grad_norm_.
# [0] 2.7140 (k=0.0500, t=0.8995, kl=0.0972, ec=4.1992)
#    (target) "They are the eggmen$"
# (generated) "oe oe oo oe ae ae ae ae ae ae ae to ae ae ae ae ae"
#
# [20] 2.9336 (k=0.0500, t=0.8994, kl=0.1252, ec=3.2758)
#    (target) "By stealing the girl of his fancy$"
# (generated) "e to to to to to to to ton ton to to to to ton to "
#
# [40] 3.1742 (k=0.0500, t=0.8994, kl=0.2801, ec=4.1061)
#    (target) "Is keeping perfectly still$"
# (generated) "oo to to to to to to to to to to to to to to to to"
#
# [60] 2.4782 (k=0.0500, t=0.8994, kl=0.1570, ec=2.7949)
#    (target) "All the money's gone, nowhere to go$"
# (generated) "e to to to to to toe to to to to to to to to to to"
#
# [80] 2.8044 (k=0.0500, t=0.8993, kl=0.1785, ec=3.6821)
#    (target) "Imagine all the people$"
# (generated) "oo to to to to to to to to so to to to so to so to"
#
# [100] 2.6834 (k=0.0500, t=0.8993, kl=0.0983, ec=2.6903)
#    (target) "And I do appreciate you being round$"
# (generated) "ou to to to to to to to to to to to to to to to to"
#
# [120] 2.6039 (k=0.0500, t=0.8992, kl=0.1469, ec=4.4361)
#    (target) "Oh, she does, yeah, she does$"
# (generated) "oo to to an to to an to an to an to an to an to an"
#
# [140] 2.6159 (k=0.0500, t=0.8992, kl=0.1223, ec=3.2519)
#    (target) "See how they fly like Lucy in the sky$"
# (generated) "he the the san san s an san san san san san san sa"
#
# [160] 2.5581 (k=0.0500, t=0.8992, kl=0.1483, ec=2.9285)
#    (target) "Remember to let her into your heart$"
# (generated) "ou tou tou tou the tou tou tou tou the tou the the"
#
# [180] 1.9977 (k=0.0500, t=0.8991, kl=0.1897, ec=4.5627)
#    (target) "I love you$"
# (generated) "I the the the the the the the the the the the the "
#
# [200] 2.8384 (k=0.0500, t=0.8991, kl=0.1014, ec=2.8794)
#    (target) "Boy, you're gonna Carry That Weight$"
# (generated) "I tou sou sou son sone sou sou son sou sou sou sou"
#
# [220] 2.5856 (k=0.0500, t=0.8990, kl=0.1125, ec=2.8113)
#    (target) "Lucy in the sky with diamonds$"
# (generated) "We the the the the the the the the the the the the"
#
# [240] 2.3597 (k=0.0500, t=0.8990, kl=0.1363, ec=3.3300)
#    (target) "Yeah, love me do$"
# (generated) "oo the the the the the the the the the the the the"
#
# [260] 2.5306 (k=0.0500, t=0.8990, kl=0.1549, ec=2.7051)
#    (target) "But she changes from day to day$"
# (generated) "An the the sou the se the se the se se se se se me"
#
# [280] 2.7782 (k=0.0500, t=0.8989, kl=0.1391, ec=2.6609)
#    (target) "Every summer we can rent a cottage,$"
# (generated) "And the the the the the san the the the san the th"
#
# [300] 2.2811 (k=0.0500, t=0.8989, kl=0.1194, ec=3.1936)
#    (target) "We're on our way home$"
# (generated) "An tou tou tou tou tou tou tou tou tou tou tou tou"
#
# [320] 1.9734 (k=0.0500, t=0.8988, kl=0.1740, ec=3.1837)
#    (target) "I want to hold your hand$"
# (generated) "All tou tou tou tou tou tou tou tou tou tou tou to"
#
# [340] 2.7784 (k=0.0500, t=0.8988, kl=0.1097, ec=3.9930)
#    (target) "Try to see it my way,$"
# (generated) "An the the the the the the the the the the the the"
#
# [360] 2.4106 (k=0.0500, t=0.8988, kl=0.0786, ec=2.8879)
#    (target) "I look at the floor and I see it needs sweeping$"
# (generated) "An the the the the the the the the the the the the"
#
# [380] 2.2080 (k=0.0500, t=0.8987, kl=0.1207, ec=3.1425)
#    (target) "Sees the sun going down$"
# (generated) "An the tou the tou the tou the the the the the the"
#
# [400] 2.3091 (k=0.0500, t=0.8987, kl=0.0740, ec=3.4910)
#    (target) "I can see them laugh at me$"
# (generated) "An to to to to to to to to to to to to to to to to"
#
# [420] 2.6481 (k=0.0500, t=0.8986, kl=0.0980, ec=2.8135)
#    (target) "Until I do, I'm telling you so you'll understand$"
# (generated) "An to to the to the to the to the to the the the t"
#
# [440] 2.5799 (k=0.0500, t=0.8986, kl=0.0976, ec=2.9575)
#    (target) "Let me hear your balalaika's ringing out$"
# (generated) "An the to gou the the the the the the the the the "
#
# [460] 2.3771 (k=0.0500, t=0.8986, kl=0.1040, ec=3.0701)
#    (target) "We all live in a yellow submarine$"
# (generated) "All tou tou sand and and and and and and and and a"
#
# [480] 2.3112 (k=0.0500, t=0.8985, kl=0.2261, ec=2.7212)
#    (target) "Pride can hurt you too$"
# (generated) "All tou tou tou tou tou tou tou tou tou tou tou to"
#
# [500] 2.3743 (k=0.0500, t=0.8985, kl=0.1462, ec=2.5603)
#    (target) "In our little hideaway beneath the waves$"
# (generated) "And the she she sere shere shere shere shere shere"
#
# Saved as vae.pt
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py:256: UserWarning: Couldn't retrieve source code for container of type VAE. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py:256: UserWarning: Couldn't retrieve source code for container of type EncoderRNN. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py:256: UserWarning: Couldn't retrieve source code for container of type DecoderRNN. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# [520] 2.2113 (k=0.0500, t=0.8984, kl=0.0842, ec=2.8557)
#    (target) "And you're working for no one but me.$"
# (generated) "All tou she love sand and and and and and and and "
#
# [540] 2.6660 (k=0.0500, t=0.8984, kl=0.0534, ec=4.5921)
#    (target) "Everywhere people stare$"
# (generated) "I the the the the the the the the the the the the "
#
# [560] 2.5044 (k=0.0500, t=0.8984, kl=0.1557, ec=3.4490)
#    (target) "Eight days a week$"
# (generated) "All the the the say the say the say the say$"
#
# [580] 2.7772 (k=0.0500, t=0.8983, kl=0.0983, ec=3.0831)
#    (target) "While my guitar gently weeps$"
# (generated) "All tou tou tou sou tou sou sou tou sou sou sand a"
#
# [600] 2.6684 (k=0.0500, t=0.8983, kl=0.0945, ec=3.4457)
#    (target) "Has left a pool of tears$"
# (generated) "All the the san the san the san$"
#
# [620] 2.0681 (k=0.0500, t=0.8982, kl=0.1520, ec=2.2813)
#    (target) "Well, you can indicate everything you see$"
# (generated) "And the the the the the the the the the the the th"
#
# [640] 2.1332 (k=0.0500, t=0.8982, kl=0.1233, ec=2.5382)
#    (target) "Give me your answer, fill in a form$"
# (generated) "And the the the the the the the the the the the th"
#
# [660] 2.6632 (k=0.0500, t=0.8982, kl=0.0786, ec=3.2784)
#    (target) "Oh, I believe in yesterday$"
# (generated) "I love me me me me me me mer mer mere mer$"
#
# [680] 2.9441 (k=0.0500, t=0.8981, kl=0.1480, ec=2.8547)
#    (target) "He said, "Danny boy, this is a showdown"$"
# (generated) "Sou the sou son the sou san the san san san san$"
#
# [700] 2.7472 (k=0.0500, t=0.8981, kl=0.1211, ec=3.3991)
#    (target) "Golden Slumbers fill your eyes$"
# (generated) "We the she she she san the she san the san$"
#
# [720] 2.6741 (k=0.0500, t=0.8980, kl=0.1119, ec=3.8486)
#    (target) "Rocky burst in, and grinning a grin$"
# (generated) "I the the she the shere shere sher the shere shere"
#
# [740] 2.1500 (k=0.0500, t=0.8980, kl=0.1206, ec=2.6441)
#    (target) "Take your time, don't hurry$"
# (generated) "I the to the the the sur tou the sar tou sure$"
#
# [760] 2.1196 (k=0.0500, t=0.8980, kl=0.0861, ec=2.6698)
#    (target) "Well, you should see her in drag$"
# (generated) "I the she she sand the she sher the sand$"
#
# [780] 2.7487 (k=0.0500, t=0.8979, kl=0.1364, ec=4.6631)
#    (target) "Oh, come on$"
# (generated) "The to to to to to to say say say say$"
#
# [800] 2.4099 (k=0.0500, t=0.8979, kl=0.1017, ec=5.8203)
#    (target) "Ah, girl, girl, girl$"
# (generated) "We the the the the the the the the sher you the sh"
#
# [820] 2.7842 (k=0.0500, t=0.8978, kl=0.1123, ec=4.6453)
#    (target) "Sleep pretty darling$"
# (generated) "Wou the sou the sou sou sone the sone$"
#
# [840] 2.0387 (k=0.0500, t=0.8978, kl=0.1284, ec=3.2071)
#    (target) "Some are dead and some are living$"
# (generated) "And the the the the sand the son$"
#
# [860] 2.1196 (k=0.0500, t=0.8978, kl=0.0913, ec=3.8930)
#    (target) "The lips I am missing$"
# (generated) "I can the san the say an the say$"
#
# [880] 2.6698 (k=0.0500, t=0.8977, kl=0.0977, ec=3.5415)
#    (target) "To shoot off the legs of his rival$"
# (generated) "All the me an a love and and and and an and and an"
#
# [900] 2.5676 (k=0.0500, t=0.8977, kl=0.1011, ec=3.3012)
#    (target) "Sleep pretty darling, do not cry$"
# (generated) "All the she sund the she she she she she she she s"
#
# [920] 2.2365 (k=0.0500, t=0.8976, kl=0.0851, ec=3.8633)
#    (target) "Don't run and hide$"
# (generated) "All to to love you sour you say you say$"
#
# [940] 2.0971 (k=0.0500, t=0.8976, kl=0.0845, ec=3.1822)
#    (target) "I want to hold your hand$"
# (generated) "All to love say say say say say say say say say sa"
#
# [960] 2.3640 (k=0.0500, t=0.8976, kl=0.0942, ec=3.7079)
#    (target) "He got monkey finger$"
# (generated) "Were the say her the say way say here you say say "
#
# [980] 2.4457 (k=0.0500, t=0.8975, kl=0.1061, ec=3.0096)
#    (target) "Came down upon his head.$"
# (generated) "And the he she her to the her to here$"
#
# [1000] 1.7110 (k=0.0500, t=0.8975, kl=0.0443, ec=2.4257)
#    (target) "Here comes the sun, and I say$"
# (generated) "And the she say sher the say$"
#
# Saved as vae.pt
# [1020] 1.9820 (k=0.0500, t=0.8974, kl=0.0729, ec=3.5319)
#    (target) "Will you still need me, will you still feed me$"
# (generated) "And the she she sund and she she she she sund and "
#
# [1040] 1.9355 (k=0.0500, t=0.8974, kl=0.0967, ec=2.7173)
#    (target) "Don't you know it's gonna be$"
# (generated) "And the she be the she she beat be the bee beat be"
#
# [1060] 2.7953 (k=0.0500, t=0.8974, kl=0.0799, ec=5.6634)
#    (target) "Aye, Sir, aye$"
# (generated) "And you dow the dow the day$"
#
# [1080] 2.4077 (k=0.0500, t=0.8973, kl=0.1235, ec=3.4178)
#    (target) "I need somebody to love$"
# (generated) "All to the to the the to the the to the the the to"
#
# [1100] 2.4227 (k=0.0500, t=0.8973, kl=0.0939, ec=3.5857)
#    (target) "Nowhere man please listen$"
# (generated) "All to gother now$"
#
# [1120] 1.9277 (k=0.0500, t=0.8972, kl=0.1124, ec=2.8939)
#    (target) "I ain't got nothing but love, babe$"
# (generated) "All to got the say say say$"
#
# [1140] 2.3948 (k=0.0500, t=0.8972, kl=0.0666, ec=2.7954)
#    (target) "Boy, you're gonna Carry That Weight$"
# (generated) "All to got the say ware an to got to got to get an"
#
# [1160] 2.7987 (k=0.0500, t=0.8972, kl=0.0802, ec=2.6470)
#    (target) "'Cause I'm going to Strawberry Fields$"
# (generated) "All the say ware you say ware ware you day say war"
#
# [1180] 2.7974 (k=0.0500, t=0.8971, kl=0.1316, ec=3.7885)
#    (target) "You say "Stop" and I say "Go, go, go".$"
# (generated) "All to got the say way$"
#
# [1200] 1.6488 (k=0.0500, t=0.8971, kl=0.0911, ec=2.6231)
#    (target) "All you need is love, all you need is love,$"
# (generated) "All the the she she seat the sher the sher the she"
#
# [1220] 1.1848 (k=0.0500, t=0.8970, kl=0.1112, ec=3.6586)
#    (target) "All together now$"
# (generated) "And to the say say say say say$"
#
# [1240] 2.5926 (k=0.0500, t=0.8970, kl=0.0883, ec=2.5662)
#    (target) "Buys a twenty carat golden ring$"
# (generated) "And to gone to gone to gone to gone to gother now$"
#
# [1260] 2.5230 (k=0.0500, t=0.8970, kl=0.0825, ec=3.7607)
#    (target) "Until I find a way$"
# (generated) "And to got the so now$"
#
# [1280] 2.4074 (k=0.0500, t=0.8969, kl=0.0607, ec=2.4069)
#    (target) "She worked at fifteen clubs a day$"
# (generated) "And to got to got to got to got and a day$"
#
# [1300] 3.2034 (k=0.0500, t=0.8969, kl=0.0651, ec=3.4868)
#    (target) "Bang! Bang! Maxwell's silver hammer$"
# (generated) "She sun the sun the say way way$"
#
# [1320] 3.2177 (k=0.0500, t=0.8968, kl=0.0907, ec=4.6847)
#    (target) "Didn't anybody see?$"
# (generated) "And you to to tou to to tou tou tou to need$"
#
# [1340] 2.0354 (k=0.0500, t=0.8968, kl=0.0599, ec=4.1452)
#    (target) "Will never die$"
# (generated) "And the the see the see the see the see$"
#
# [1360] 2.1222 (k=0.0500, t=0.8968, kl=0.0510, ec=3.3084)
#    (target) "Oh now I roll a stoney$"
# (generated) "I the the the the the the the seeling$"
#
# [1380] 1.7342 (k=0.0500, t=0.8967, kl=0.0570, ec=2.4271)
#    (target) "All together now I dig a pony$"
# (generated) "And the she s me she say she sher sher say$"
#
# [1400] 1.9593 (k=0.0500, t=0.8967, kl=0.0588, ec=2.9137)
#    (target) "And all I have to do is think of her$"
# (generated) "And the the she some the sund and sund$"
#
# [1420] 2.3292 (k=0.0500, t=0.8966, kl=0.0938, ec=3.1811)
#    (target) "How could she say to me$"
# (generated) "And to love to love some$"
#
# [1440] 1.8126 (k=0.0500, t=0.8966, kl=0.0916, ec=3.1385)
#    (target) "But to love her is to need her everywhere$"
# (generated) "And the she see the see the see$"
#
# [1460] 2.3517 (k=0.0500, t=0.8966, kl=0.0805, ec=3.5890)
#    (target) "I feel happy inside$"
# (generated) "And the the see the see the seed and and and and a"
#
# [1480] 2.2427 (k=0.0500, t=0.8965, kl=0.1542, ec=3.5896)
#    (target) "Eight days a week$"
# (generated) "Whe the say she say she say she say she say$"
#
# [1500] 2.2211 (k=0.0500, t=0.8965, kl=0.0761, ec=3.2820)
#    (target) "Changing my life with a wave of her hand$"
# (generated) "Well to love to love to love and you to love to to"
#
# Saved as vae.pt
# [1520] 1.9993 (k=0.0500, t=0.8964, kl=0.1124, ec=2.8754)
#    (target) "Nothing's gonna change my world$"
# (generated) "Whe to love you the a love you way and and you the"
#
# [1540] 2.4111 (k=0.0500, t=0.8964, kl=0.1429, ec=2.9671)
#    (target) "Are drifting through my opened mind$"
# (generated) "All to love the some$"
#
# [1560] 2.2443 (k=0.0500, t=0.8964, kl=0.1058, ec=3.0744)
#    (target) "Girl I'd like to be under the sea$"
# (generated) "All to the the to love the to love to love to me t"
#
# [1580] 2.4179 (k=0.0500, t=0.8963, kl=0.0730, ec=3.0519)
#    (target) "Why do I always have to say, love$"
# (generated) "Some to love to love to love will to love to love "
#
# [1600] 2.1304 (k=0.0500, t=0.8963, kl=0.0834, ec=2.6515)
#    (target) "Speaking words of wisdom, let it be$"
# (generated) "All to love wing the see to see$"
#
# [1620] 2.0325 (k=0.0500, t=0.8962, kl=0.0729, ec=2.6181)
#    (target) "We hope you will enjoy the show,$"
# (generated) "I love to love to love some to see$"
#
# [1640] 2.2184 (k=0.0500, t=0.8962, kl=0.0878, ec=3.0424)
#    (target) "He knows that they're the fools$"
# (generated) "All the she sun the some$"
#
# [1660] 2.2503 (k=0.0500, t=0.8962, kl=0.0671, ec=2.8659)
#    (target) "Carry That Weight a long time$"
# (generated) "All to love the she she so love wing$"
#
# [1680] 2.6755 (k=0.0500, t=0.8961, kl=0.1192, ec=3.6529)
#    (target) "You say "Stop", I say "Go, go, go".$"
# (generated) "All to get to got to got to get to love love love "
#
# [1700] 2.3453 (k=0.0500, t=0.8961, kl=0.0992, ec=3.8023)
#    (target) "Don't run and hide$"
# (generated) "See to got the sun the sun to love sun$"
#
# [1720] 1.6267 (k=0.0500, t=0.8960, kl=0.0628, ec=3.3561)
#    (target) "You can talk to me$"
# (generated) "And the she she sun the sun$"
#
# [1740] 2.1691 (k=0.0500, t=0.8960, kl=0.0546, ec=3.0087)
#    (target) "I never needed anybody's help in any way$"
# (generated) "And to got to got to got to got to got to got to g"
#
# [1760] 1.8728 (k=0.0500, t=0.8960, kl=0.0844, ec=3.2165)
#    (target) "You'll let me be your man$"
# (generated) "Sou to got the she she she she she she she she she"
#
# [1780] 2.3136 (k=0.0500, t=0.8959, kl=0.0584, ec=4.1409)
#    (target) "Ah, la, la, la, la He's a real nowhere man$"
# (generated) "And the she she she she she she she she sher now$"
#
# [1800] 2.1432 (k=0.0500, t=0.8959, kl=0.0915, ec=2.8519)
#    (target) "Dance You say it's your birthday$"
# (generated) "And the she she she she say she say she she she sh"
#
# [1820] 1.8855 (k=0.0500, t=0.8958, kl=0.1047, ec=3.5757)
#    (target) "All the lonely people$"
# (generated) "Sou she say she say she say she say she say$"
#
# [1840] 1.9682 (k=0.0500, t=0.8958, kl=0.0828, ec=2.7123)
#    (target) "Make it easy to be near you$"
# (generated) "Were to got to got to got to got to be$"
#
# [1860] 2.0273 (k=0.0500, t=0.8958, kl=0.0545, ec=4.2329)
#    (target) "I can't hide$"
# (generated) "And the she she she she she be$"
#
# [1880] 2.3243 (k=0.0500, t=0.8957, kl=0.0787, ec=3.0523)
#    (target) "Misunderstanding all you see$"
# (generated) "All to got the she sun$"
#
# [1900] 2.1965 (k=0.0500, t=0.8957, kl=0.1005, ec=4.0643)
#    (target) "A long long time ago$"
# (generated) "All to got to got to got the say sun the say$"
#
# [1920] 2.3431 (k=0.0500, t=0.8956, kl=0.0959, ec=3.8191)
#    (target) "I feel happy inside$"
# (generated) "All the she she she she she she she she she she sh"
#
# [1940] 2.2914 (k=0.0500, t=0.8956, kl=0.1728, ec=3.1147)
#    (target) "You say "Stop" and I say "Go, go, go".$"
# (generated) "All together now$"
#
# [1960] 1.8467 (k=0.0500, t=0.8956, kl=0.0738, ec=2.9614)
#    (target) "What makes you think you're$"
# (generated) "All together now$"
#
# [1980] 2.2283 (k=0.0500, t=0.8955, kl=0.0792, ec=2.8579)
#    (target) "Boy you're gonna carry that weight,$"
# (generated) "All together now$"
#
# [2000] 2.3938 (k=0.0500, t=0.8955, kl=0.0708, ec=3.3861)
#    (target) "Can I bring my friend to tea$"
# (generated) "All together now$"
#
# Saved as vae.pt
# [2020] 0.9819 (k=0.0500, t=0.8954, kl=0.1046, ec=3.2778)
#    (target) "Love you, love you$"
# (generated) "All to got to got to got to got be$"
#
# [2040] 1.8597 (k=0.0500, t=0.8954, kl=0.1079, ec=3.7360)
#    (target) "Oh, she does, yeah, she does$"
# (generated) "All to got to good you she she she see$"
#
# [2060] 2.2757 (k=0.0500, t=0.8954, kl=0.0452, ec=3.6083)
#    (target) "I never give you my number$"
# (generated) "All together now$"
#
# [2080] 1.8852 (k=0.0500, t=0.8953, kl=0.0757, ec=2.9434)
#    (target) "The man with the foolish grin$"
# (generated) "All together now$"
#
# [2100] 2.4925 (k=0.0500, t=0.8953, kl=0.1119, ec=3.0419)
#    (target) "And I will sing a lullaby. Golden slumbers,$"
# (generated) "All to got the she she she she she she she she she"
#
# [2120] 1.9870 (k=0.0500, t=0.8952, kl=0.0824, ec=2.8172)
#    (target) "No, I never saw them at all$"
# (generated) "All to got the sun the sun$"
#
# [2140] 2.7107 (k=0.0500, t=0.8952, kl=0.0935, ec=3.5868)
#    (target) "To shoot off the legs of his rival$"
# (generated) "All to good to to sun$"
#
# [2160] 2.1517 (k=0.0500, t=0.8952, kl=0.1032, ec=2.9835)
#    (target) "But he knew it wouldn't last$"
# (generated) "All the sun the sun$"
#
# [2180] 2.0843 (k=0.0500, t=0.8951, kl=0.0597, ec=3.0626)
#    (target) "For fussing and fighting, my friend$"
# (generated) "All together now$"
#
# [2200] 3.3546 (k=0.0500, t=0.8951, kl=0.1228, ec=7.3004)
#    (target) "Juba juba juba$"
# (generated) "And the sun the sun$"
#
# [2220] 1.7857 (k=0.0500, t=0.8950, kl=0.0748, ec=2.8054)
#    (target) "And if I say the word,$"
# (generated) "All to the sun the sun$"
#
# [2240] 2.3970 (k=0.0500, t=0.8950, kl=0.0767, ec=5.1066)
#    (target) "Oh I do a road hog$"
# (generated) "And to got to got to got to me$"
#
# [2260] 2.6667 (k=0.0500, t=0.8950, kl=0.0954, ec=3.3397)
#    (target) "Dragged a comb across my head$"
# (generated) "And the say say sun her now$"
#
# [2280] 1.7868 (k=0.0500, t=0.8949, kl=0.0888, ec=4.0295)
#    (target) "Will never die$"
# (generated) "I can the sun the say the say$"
#
# [2300] 2.1733 (k=0.0500, t=0.8949, kl=0.0661, ec=2.8428)
#    (target) "Carry That Weight a long time$"
# (generated) "All to got to here you dond$"
#
# [2320] 1.2054 (k=0.0500, t=0.8948, kl=0.1506, ec=3.4564)
#    (target) "Nah nah nah nah nah nah, nah nah nah, hey Jude$"
# (generated) "And a way the say the say way$"
#
# [2340] 2.7322 (k=0.0500, t=0.8948, kl=0.0941, ec=3.9709)
#    (target) "Feeling two foot small$"
# (generated) "And a way the see the say$"
#
# [2360] 2.0359 (k=0.0500, t=0.8948, kl=0.1067, ec=3.8044)
#    (target) "You were perverted too$"
# (generated) "Wher now I wand it the sun$"
#
# [2380] 2.2376 (k=0.0500, t=0.8947, kl=0.0828, ec=4.0691)
#    (target) "I am the walrus$"
# (generated) "And you see to got to the sun$"
#
# [2400] 2.1077 (k=0.0500, t=0.8947, kl=0.0961, ec=3.5615)
#    (target) "They say it's your birthday$"
# (generated) "All together now$"
#
# [2420] 1.7883 (k=0.0500, t=0.8946, kl=0.0763, ec=3.0737)
#    (target) "I never give you my number$"
# (generated) "All together now$"
#
# [2440] 2.9107 (k=0.0500, t=0.8946, kl=0.1418, ec=4.2782)
#    (target) "Say "Goodbye, goodbye, bye, bye".$"
# (generated) "Sou the say the see the see$"
#
# [2460] 1.5190 (k=0.0500, t=0.8946, kl=0.0942, ec=2.6058)
#    (target) "And the banker never wears a mac$"
# (generated) "All together now$"
#
# [2480] 2.1284 (k=0.0500, t=0.8945, kl=0.1071, ec=2.4864)
#    (target) "Are you going to be in my dreams tonight?$"
# (generated) "All together now$"
#
# [2500] 1.9991 (k=0.0500, t=0.8945, kl=0.0569, ec=2.7842)
#    (target) "Yes, I get by with a little help from my friends$"
# (generated) "I love you see to see$"
#
# Saved as vae.pt
# [2520] 1.6616 (k=0.0500, t=0.8944, kl=0.0681, ec=2.5924)
#    (target) "Lucy in the sky with diamonds$"
# (generated) "And the say sun the say sun$"
#
# [2540] 3.0463 (k=0.0500, t=0.8944, kl=0.0937, ec=5.0236)
#    (target) "Tres bien ensemble$"
# (generated) "All together now$"
#
# [2560] 1.1866 (k=0.0500, t=0.8944, kl=0.1713, ec=3.4346)
#    (target) "Nah nah nah nah nah nah, nah nah nah, hey Jude$"
# (generated) "She say sun the say sunder now$"
#
# [2580] 2.1370 (k=0.0500, t=0.8943, kl=0.0956, ec=2.4670)
#    (target) "Well, he put some tacks on teachers chair$"
# (generated) "All together now$"
#
# [2600] 1.9753 (k=0.0500, t=0.8943, kl=0.1042, ec=2.9628)
#    (target) "No, I never heard it at all$"
# (generated) "All together now$"
#
# [2620] 2.5972 (k=0.0500, t=0.8942, kl=0.1010, ec=3.2740)
#    (target) "And little children laugh at him behind his back.$"
# (generated) "All together now$"
#
# [2640] 2.0922 (k=0.0500, t=0.8942, kl=0.0486, ec=3.0315)
#    (target) "Please, please me, woah yeah, like I please you$"
# (generated) "I love you see the seah, you see$"
#
# [2660] 2.1909 (k=0.0500, t=0.8942, kl=0.0690, ec=2.4114)
#    (target) "That is I think I disagree Let me take you down$"
# (generated) "All together now$"
#
# [2680] 2.0963 (k=0.0500, t=0.8941, kl=0.0584, ec=2.5752)
#    (target) "Yes, I get by with a little help from my friends$"
# (generated) "All together now$"
#
# [2700] 1.8976 (k=0.0500, t=0.8941, kl=0.0670, ec=2.3311)
#    (target) "Man, you should have seen them kicking$"
# (generated) "All together now$"
#
# [2720] 2.4117 (k=0.0500, t=0.8940, kl=0.0927, ec=3.9364)
#    (target) "I feel happy inside$"
# (generated) "I love you see the sun$"
#
# [2740] 1.8073 (k=0.0500, t=0.8940, kl=0.0732, ec=2.5000)
#    (target) "Well, I knew what I could not say$"
# (generated) "All together now$"
#
# [2760] 2.4159 (k=0.0500, t=0.8940, kl=0.0707, ec=5.0892)
#    (target) "One sweet dream$"
# (generated) "All together now$"
#
# [2780] 2.0474 (k=0.0500, t=0.8939, kl=0.0660, ec=4.0513)
#    (target) "Head in a cloud$"
# (generated) "I love you know I love you don't be to be to be to"
#
# [2800] 1.8066 (k=0.0500, t=0.8939, kl=0.0987, ec=2.9324)
#    (target) "Something in the way she woos me$"
# (generated) "I love you know$"
#
# [2820] 2.5112 (k=0.0500, t=0.8938, kl=0.0866, ec=3.2463)
#    (target) "Pretty little policemen in a row$"
# (generated) "All together now$"
#
# [2840] 2.1191 (k=0.0500, t=0.8938, kl=0.0514, ec=2.7654)
#    (target) "Now it looks as though they're here to stay$"
# (generated) "All together now$"
#
# [2860] 1.9152 (k=0.0500, t=0.8938, kl=0.0725, ec=4.0519)
#    (target) "Could never die$"
# (generated) "All together now$"
#
# [2880] 1.5286 (k=0.0500, t=0.8937, kl=0.0740, ec=2.8981)
#    (target) "I'll get to you somehow$"
# (generated) "All together now$"
#
# [2900] 1.6615 (k=0.0500, t=0.8937, kl=0.0667, ec=2.2892)
#    (target) "All the girls around her say she's got it coming$"
# (generated) "All together now$"
#
# [2920] 2.8939 (k=0.0500, t=0.8936, kl=0.0805, ec=3.1252)
#    (target) "Quando paramucho mi amore defelice corazon$"
# (generated) "All together now$"
#
# [2940] 1.9512 (k=0.0500, t=0.8936, kl=0.0675, ec=2.8684)
#    (target) "Where do they all come from?$"
# (generated) "All together now$"
#
# [2960] 1.7293 (k=0.0500, t=0.8936, kl=0.0898, ec=3.3512)
#    (target) "But I just had to look$"
# (generated) "All together now$"
#
# [2980] 2.0691 (k=0.0500, t=0.8935, kl=0.0537, ec=3.2431)
#    (target) "Sleep pretty darling do not cry,$"
# (generated) "All together now$"
#
# [3000] 1.9818 (k=0.0500, t=0.8935, kl=0.0896, ec=3.5587)
#    (target) "Whoa, love me do Love, love me do$"
# (generated) "I can the gond a love you see the gord$"
#
# Saved as vae.pt
# [3020] 2.3624 (k=0.0500, t=0.8934, kl=0.0606, ec=3.1261)
#    (target) "I'm crying Sitting on a cornflake$"
# (generated) "Where way she way she way$"
#
# [3040] 2.5277 (k=0.0500, t=0.8934, kl=0.0479, ec=3.9776)
#    (target) "Until I find a way$"
# (generated) "All together now$"
#
# [3060] 0.3343 (k=0.0500, t=0.8934, kl=0.1098, ec=1.5136)
#    (target) "All together now$"
# (generated) "All together now$"
#
# [3080] 1.7864 (k=0.0500, t=0.8933, kl=0.0529, ec=3.0701)
#    (target) "But I never heard them ringing$"
# (generated) "I to go the sund$"
#
# [3100] 2.0175 (k=0.0500, t=0.8933, kl=0.0575, ec=3.0213)
#    (target) "Smiles awake you when you rise$"
# (generated) "All together now$"
#
# [3120] 2.5891 (k=0.0500, t=0.8932, kl=0.0655, ec=3.0651)
#    (target) "Yesterday, all my troubles seemed so far away$"
# (generated) "All together now$"
#
# [3140] 1.8407 (k=0.0500, t=0.8932, kl=0.0532, ec=2.7637)
#    (target) "Smiles awake you when you rise$"
# (generated) "All together now$"
#
# [3160] 2.4288 (k=0.0500, t=0.8932, kl=0.0666, ec=3.2593)
#    (target) "Because Oh! Darling, please believe me$"
# (generated) "All together now$"
#
# [3180] 2.2746 (k=0.0500, t=0.8931, kl=0.0710, ec=3.1923)
#    (target) "From his hands as he walks from the grave$"
# (generated) "All together now$"
#
# [3200] 1.7762 (k=0.0500, t=0.8931, kl=0.0554, ec=2.5670)
#    (target) "It's such a feelin' that my love$"
# (generated) "All together now$"
#
# [3220] 1.9071 (k=0.0500, t=0.8930, kl=0.0380, ec=2.8789)
#    (target) "You tell me that it's evolution$"
# (generated) "I to gond the gonna want the gonna be$"
#
# [3240] 2.6047 (k=0.0500, t=0.8930, kl=0.1295, ec=3.4742)
#    (target) "And got myself a steady job$"
# (generated) "I to to go the want the some$"
#
# [3260] 2.2158 (k=0.0500, t=0.8930, kl=0.0620, ec=2.8666)
#    (target) "Shaves in the dark, tryin to save paper$"
# (generated) "All together now$"
#
# [3280] 1.9031 (k=0.0500, t=0.8929, kl=0.0758, ec=3.2727)
#    (target) "You want so much it make you sorry$"
# (generated) "And the see the seed the see$"
#
# [3300] 2.7418 (k=0.0500, t=0.8929, kl=0.0721, ec=3.4530)
#    (target) "Ah, la, la, la, la Doesn't have a point of view$"
# (generated) "I the so love you she want the so me$"
#
# [3320] 2.0677 (k=0.0500, t=0.8928, kl=0.0483, ec=2.6924)
#    (target) "We hope you will enjoy the show,$"
# (generated) "I love you know the sun$"
#
# [3340] 2.2732 (k=0.0500, t=0.8928, kl=0.0363, ec=3.1658)
#    (target) "In the church where a wedding has been$"
# (generated) "I the say she say she say she plove you shound$"
#
# [3360] 1.7252 (k=0.0500, t=0.8928, kl=0.0546, ec=2.5771)
#    (target) "Till there was you There were birds in the sky$"
# (generated) "I love you see to love you see$"
#
# [3380] 1.8676 (k=0.0500, t=0.8927, kl=0.0655, ec=2.9132)
#    (target) "I never needed anybody's help in any way$"
# (generated) "I can't she gone the sun$"
#
# [3400] 1.9434 (k=0.0500, t=0.8927, kl=0.0657, ec=2.4503)
#    (target) "Though I know I'll never lose affection$"
# (generated) "And the sunshing the sunshing the say she say$"
#
# [3420] 1.5178 (k=0.0500, t=0.8926, kl=0.0612, ec=5.0378)
#    (target) "And everywhere$"
# (generated) "I love you know I love you know I love you say she"
#
# [3440] 0.8013 (k=0.0500, t=0.8926, kl=0.1245, ec=2.9728)
#    (target) "Love you, love you$"
# (generated) "Ind the sunshing the sun$"
#
# [3460] 1.1877 (k=0.0500, t=0.8926, kl=0.1409, ec=2.9631)
#    (target) "Good day sunshine.$"
# (generated) "Ind the sunshing the sun$"
#
# [3480] 0.5425 (k=0.0500, t=0.8925, kl=0.0637, ec=2.3898)
#    (target) "All together now$"
# (generated) "And the sunshing a love you see the sun$"
#
# [3500] 1.3136 (k=0.0500, t=0.8925, kl=0.0676, ec=3.2546)
#    (target) "I want to hold your hand$"
# (generated) "And the sun the sunshing and the sun$"
#
# Saved as vae.pt
# [3520] 3.2339 (k=0.0500, t=0.8924, kl=0.0683, ec=4.1012)
#    (target) "Bup-a-lup-bup! Falling, yes I am falling,$"
# (generated) "And the sunshing to me to the want to me$"
#
# [3540] 2.1224 (k=0.0500, t=0.8924, kl=0.0548, ec=3.8017)
#    (target) "It's easy if you try$"
# (generated) "I can the sunshing a love you$"
#
# [3560] 1.7316 (k=0.0500, t=0.8924, kl=0.0390, ec=2.4161)
#    (target) "carry that weight for a long time$"
# (generated) "All together now$"
#
# [3580] 2.7201 (k=0.0500, t=0.8923, kl=0.0529, ec=3.1599)
#    (target) "Saving up to buy him some clothes$"
# (generated) "All together now$"
#
# [3600] 2.4821 (k=0.0500, t=0.8923, kl=0.0730, ec=3.4155)
#    (target) "Wigwam frightened of the dark$"
# (generated) "All together now$"
#
# [3620] 2.2819 (k=0.0500, t=0.8922, kl=0.1692, ec=3.3068)
#    (target) "I think I know I mean a "Yes"$"
# (generated) "All together now$"
#
# [3640] 2.2711 (k=0.0500, t=0.8922, kl=0.1038, ec=4.2017)
#    (target) "I told her I didn't$"
# (generated) "I want to got to get be to get be$"
#
# [3660] 2.0169 (k=0.0500, t=0.8922, kl=0.3671, ec=4.5447)
#    (target) "Back in the USSR$"
# (generated) "All together now$"
#
# [3680] 1.9241 (k=0.0500, t=0.8921, kl=0.0593, ec=3.1817)
#    (target) "Turn my face to the wall$"
# (generated) "I to to to to the sun$"
#
# [3700] 2.1110 (k=0.0500, t=0.8921, kl=0.0583, ec=2.6923)
#    (target) "All right, all right In the town where I was born$"
# (generated) "I can the she say she she she say$"
#
# [3720] 1.3286 (k=0.0500, t=0.8920, kl=0.0775, ec=3.7368)
#    (target) "I don't know, I don't know$"
# (generated) "All together now$"
#
# [3740] 1.9600 (k=0.0500, t=0.8920, kl=0.0581, ec=3.0978)
#    (target) "Your song will fill the air$"
# (generated) "I to love you know$"
#
# [3760] 1.3995 (k=0.0500, t=0.8920, kl=0.0790, ec=2.5360)
#    (target) "But I never heard it singing$"
# (generated) "All together now$"
#
# [3780] 0.6462 (k=0.0500, t=0.8919, kl=0.0942, ec=2.1832)
#    (target) "You know I love you$"
# (generated) "All together now$"
#
# [3800] 2.2650 (k=0.0500, t=0.8919, kl=0.0755, ec=2.7460)
#    (target) "And looking up I noticed I was late$"
# (generated) "All together now$"
#
# [3820] 1.4531 (k=0.0500, t=0.8918, kl=0.0569, ec=2.8139)
#    (target) "In my life, I love you more$"
# (generated) "And I love you know$"
#
# [3840] 1.8780 (k=0.0500, t=0.8918, kl=0.0459, ec=3.2655)
#    (target) "I can see them laugh at me$"
# (generated) "I love you know$"
#
# [3860] 2.8424 (k=0.0500, t=0.8918, kl=0.0959, ec=3.5927)
#    (target) "Father McKenzie, wiping the dirt$"
# (generated) "And I love you know$"
#
# [3880] 3.1611 (k=0.0500, t=0.8917, kl=0.0689, ec=2.8378)
#    (target) "Sgt. Pepper's Lonely Hearts Club Band$"
# (generated) "And I love you know$"
#
# [3900] 1.7839 (k=0.0500, t=0.8917, kl=0.0835, ec=4.2124)
#    (target) "I am the walrus$"
# (generated) "And the sunshing to be to be$"
#
# [3920] 1.6096 (k=0.0500, t=0.8916, kl=0.0843, ec=2.9159)
#    (target) "Get back, get back, get back Once there was a way,$"
# (generated) "All together now$"
#
# [3940] 2.1176 (k=0.0500, t=0.8916, kl=0.0712, ec=3.2069)
#    (target) "Will you still be sending me a Valentine.$"
# (generated) "All together now$"
#
# [3960] 2.3708 (k=0.0500, t=0.8916, kl=0.0502, ec=3.1024)
#    (target) "Dear Prudence, greet the brand new day$"
# (generated) "All together now$"
#
# [3980] 2.5263 (k=0.0500, t=0.8915, kl=0.0540, ec=3.9678)
#    (target) "Was way beyond compare$"
# (generated) "And the way sunshing the way sun$"
#
# [4000] 2.4342 (k=0.0500, t=0.8915, kl=0.0778, ec=3.3167)
#    (target) "It's getting hard to be someone$"
# (generated) "And the say sunshing$"
#
# Saved as vae.pt
# [4020] 2.6193 (k=0.0500, t=0.8914, kl=0.0682, ec=3.6264)
#    (target) "Me back again. Falling, yes I am falling,$"
# (generated) "All together now$"
#
# [4040] 1.6357 (k=0.0500, t=0.8914, kl=0.0785, ec=3.4361)
#    (target) "And I have missed things$"
# (generated) "All together now$"
#
# [4060] 2.1292 (k=0.0500, t=0.8914, kl=0.0444, ec=2.8611)
#    (target) "And I do appreciate you being round$"
# (generated) "All together now$"
#
# [4080] 1.1740 (k=0.0500, t=0.8913, kl=0.0707, ec=3.0579)
#    (target) "You got to be free$"
# (generated) "And the see to be be$"
#
# [4100] 2.3534 (k=0.0500, t=0.8913, kl=0.1619, ec=3.5752)
#    (target) "Well, I saw her yesterday-yi-yay$"
# (generated) "And the got to me$"
#
# [4120] 1.7981 (k=0.0500, t=0.8912, kl=0.0480, ec=2.5946)
#    (target) "And I do appreciate you being round$"
# (generated) "And the say the way sun$"
#
# [4140] 2.0482 (k=0.0500, t=0.8912, kl=0.0535, ec=3.2182)
#    (target) "The one and only Billy Shears$"
# (generated) "And the sun the sun$"
#
# [4160] 2.0206 (k=0.0500, t=0.8912, kl=0.0879, ec=3.1881)
#    (target) "She could steal, but she could not rob$"
# (generated) "And the sunshing to me$"
#
# [4180] 1.5796 (k=0.0500, t=0.8911, kl=0.1492, ec=2.3310)
#    (target) "You don't know how lucky you are, boy$"
# (generated) "And the sunshing a love you me$"
#
# [4200] 1.1467 (k=0.0500, t=0.8911, kl=0.0618, ec=2.2510)
#    (target) "Back to where you once belonged$"
# (generated) "I can the sun the sun$"
#
# [4220] 1.8503 (k=0.0500, t=0.8910, kl=0.0874, ec=2.8157)
#    (target) "But she gets it while she can Get back, get back$"
# (generated) "And the sun the say the say$"
#
# [4240] 1.9862 (k=0.0500, t=0.8910, kl=0.0443, ec=3.0582)
#    (target) "You tell me that it's evolution$"
# (generated) "And I say the say the say$"
#
# [4260] 1.3217 (k=0.0500, t=0.8910, kl=0.2398, ec=3.3724)
#    (target) "Back in the USSR$"
# (generated) "Well to love you know$"
#
# [4280] 1.5524 (k=0.0500, t=0.8909, kl=0.0436, ec=2.5063)
#    (target) "Changing my life with a wave of her hand$"
# (generated) "And I say the sun her now$"
#
# [4300] 1.9876 (k=0.0500, t=0.8909, kl=0.0730, ec=3.2884)
#    (target) "He blew his mind out in a car$"
# (generated) "Well you know I love you$"
#
# [4320] 1.1612 (k=0.0500, t=0.8908, kl=0.0638, ec=2.3424)
#    (target) "All you need is love, love. Love is all you need.$"
# (generated) "All together now$"
#
# [4340] 2.2279 (k=0.0500, t=0.8908, kl=0.0431, ec=2.9666)
#    (target) "The English Army had just won the war$"
# (generated) "I love you see$"
#
# [4360] 2.0160 (k=0.0500, t=0.8908, kl=0.0830, ec=3.1884)
#    (target) "I sit, and meanwhile back.$"
# (generated) "See to she want to me$"
#
# [4380] 1.7542 (k=0.0500, t=0.8907, kl=0.1000, ec=3.9035)
#    (target) "Come on, come on, come, come on baby now$"
# (generated) "All together now$"
#
# [4400] 1.7867 (k=0.0500, t=0.8907, kl=0.0572, ec=3.0703)
#    (target) "All good children go to heaven$"
# (generated) "All together now$"
#
# [4420] 1.6701 (k=0.0500, t=0.8906, kl=0.0816, ec=2.3767)
#    (target) "You don't know how lucky you are, boy$"
# (generated) "All together now$"
#
# [4440] 2.5629 (k=0.0500, t=0.8906, kl=0.0711, ec=3.4185)
#    (target) "The man of a thousand voices$"
# (generated) "All together now$"
#
# [4460] 2.6160 (k=0.0500, t=0.8906, kl=0.0574, ec=4.6549)
#    (target) "I break down$"
# (generated) "All together now$"
#
# [4480] 0.2195 (k=0.0500, t=0.8905, kl=0.0740, ec=1.1593)
#    (target) "All together now$"
# (generated) "I all together now$"
#
# [4500] 1.8858 (k=0.0500, t=0.8905, kl=0.1078, ec=3.9474)
#    (target) "And before too long$"
# (generated) "I can the sun her now$"
#
# Saved as vae.pt
# [4520] 1.4354 (k=0.0500, t=0.8904, kl=0.0721, ec=3.0424)
#    (target) "While you see it your way$"
# (generated) "All together now$"
#
# [4540] 0.2293 (k=0.0500, t=0.8904, kl=0.1316, ec=1.2569)
#    (target) "All together now$"
# (generated) "All together now$"
#
# [4560] 0.9098 (k=0.0500, t=0.8904, kl=0.0968, ec=3.6236)
#    (target) "I love you$"
# (generated) "All together now$"
#
# [4580] 2.1545 (k=0.0500, t=0.8903, kl=0.0913, ec=3.4703)
#    (target) "If she's gone I can't go on$"
# (generated) "All together now$"
#
# [4600] 1.6757 (k=0.0500, t=0.8903, kl=0.0447, ec=2.7997)
#    (target) "Oh, since I saw her standing there$"
# (generated) "All together now$"
#
# [4620] 2.0059 (k=0.0500, t=0.8902, kl=0.0627, ec=3.4276)
#    (target) "The sun is up, the sky is blue$"
# (generated) "All together now$"
#
# [4640] 1.8975 (k=0.0500, t=0.8902, kl=0.0521, ec=3.0118)
#    (target) "Smiles await you when you rise$"
# (generated) "I want to her now$"
#
# [4660] 1.9069 (k=0.0500, t=0.8902, kl=0.0448, ec=3.7133)
#    (target) "Crying for the day$"
# (generated) "I love you know$"
#
# [4680] 1.1983 (k=0.0500, t=0.8901, kl=0.0631, ec=2.5260)
#    (target) "Get back to where you once belonged$"
# (generated) "All together now$"
#
# [4700] 3.4526 (k=0.0500, t=0.8901, kl=0.0902, ec=6.1602)
#    (target) "My Michelle$"
# (generated) "All together now$"
#
# [4720] 1.7669 (k=0.0500, t=0.8900, kl=0.0574, ec=2.7239)
#    (target) "Someday I'm going to make her mine Oh yeah,$"
# (generated) "All together now$"
#
# [4740] 1.7887 (k=0.0500, t=0.8900, kl=0.0843, ec=3.2611)
#    (target) "But I never heard it singing$"
# (generated) "All together now$"
#
# [4760] 2.0847 (k=0.0500, t=0.8900, kl=0.0666, ec=2.6317)
#    (target) "In the Isle of Wight, if it's not too dear$"
# (generated) "And I can't say that she sunshing a want to be$"
#
# [4780] 2.4821 (k=0.0500, t=0.8899, kl=0.0627, ec=3.5692)
#    (target) "Are drifting through my opened mind$"
# (generated) "All together now$"
#
# [4800] 2.5965 (k=0.0500, t=0.8899, kl=0.0561, ec=3.8545)
#    (target) "Remember to let her into your heart$"
# (generated) "All together now$"
#
# [4820] 1.3095 (k=0.0500, t=0.8898, kl=0.0975, ec=2.5215)
#    (target) "But I thought that you might like to know$"
# (generated) "And I can the sun a love you man$"
#
# [4840] 0.2740 (k=0.0500, t=0.8898, kl=0.1180, ec=1.4521)
#    (target) "All together now$"
# (generated) "All together now$"
#
# [4860] 2.5195 (k=0.0500, t=0.8898, kl=0.1028, ec=3.4060)
#    (target) "(Lies beneath the ocean waves)$"
# (generated) "All together now$"
#
# [4880] 1.1808 (k=0.0500, t=0.8897, kl=0.0965, ec=2.4976)
#    (target) "Now, let me hold your hand$"
# (generated) "I can the sun, I love me do$"
#
# [4900] 2.0376 (k=0.0500, t=0.8897, kl=0.0628, ec=2.7206)
#    (target) "Only time will tell if I am right or I am wrong$"
# (generated) "All together now$"
#
# [4920] 1.9743 (k=0.0500, t=0.8896, kl=0.0783, ec=4.7982)
#    (target) "Tomorrow I'll miss you$"
# (generated) "Some the sun hide$"
#
# [4940] 2.5424 (k=0.0500, t=0.8896, kl=0.1043, ec=4.2350)
#    (target) "He got toe jam football$"
# (generated) "And I can the sun her now$"
#
# [4960] 1.8437 (k=0.0500, t=0.8896, kl=0.0655, ec=3.0182)
#    (target) "You stick around and it may show$"
# (generated) "And the sun the sun her now$"
#
# [4980] 3.4999 (k=0.0500, t=0.8895, kl=0.1246, ec=5.5103)
#    (target) "Jai Guru Deva$"
# (generated) "All together now$"
#
# [5000] 1.4392 (k=0.0500, t=0.8895, kl=0.0593, ec=2.8823)
#    (target) "I'd like to be under the sea$"
# (generated) "All together now$"
#
# Saved as vae.pt
# [5020] 2.0060 (k=0.0500, t=0.8894, kl=0.0626, ec=3.3322)
#    (target) "Are drifting through my opened mind$"
# (generated) "All together now$"
#
# [5040] 2.2977 (k=0.0500, t=0.8894, kl=0.0809, ec=3.1071)
#    (target) "To shoot off the legs of his rival$"
# (generated) "All together now$"
#
# [5060] 1.1283 (k=0.0500, t=0.8894, kl=0.0731, ec=2.2939)
#    (target) "Someone like you Love, love me do$"
# (generated) "All together now$"
#
# [5080] 1.2891 (k=0.0500, t=0.8893, kl=0.1581, ec=3.4618)
#    (target) "Back in the US$"
# (generated) "All together now$"
#
# [5100] 1.6518 (k=0.0500, t=0.8893, kl=0.0934, ec=3.7945)
#    (target) "And I have missed things$"
# (generated) "All together now$"
#
# [5120] 1.8562 (k=0.0500, t=0.8892, kl=0.0652, ec=2.6799)
#    (target) "Yes, I'm certain that it happens all the time$"
# (generated) "All together now$"
#
# [5140] 1.9638 (k=0.0500, t=0.8892, kl=0.0651, ec=2.9031)
#    (target) "Take these broken wings and learn to fly$"
# (generated) "I love you see$"
#
# [5160] 1.5132 (k=0.0500, t=0.8892, kl=0.0885, ec=3.5688)
#    (target) "Come on and work it on out$"
# (generated) "All together now$"
#
# [5180] 1.4651 (k=0.0500, t=0.8891, kl=0.0639, ec=3.5106)
#    (target) "Nothing is real$"
# (generated) "You know I love you see$"
#
# [5200] 1.5841 (k=0.0500, t=0.8891, kl=0.0929, ec=2.9534)
#    (target) "Knows not where he's going to$"
# (generated) "All together now$"
#
# [5220] 1.7488 (k=0.0500, t=0.8890, kl=0.0943, ec=3.3767)
#    (target) "Eight days a week Eight days a week$"
# (generated) "All together now$"
#
# [5240] 1.9263 (k=0.0500, t=0.8890, kl=0.0546, ec=3.0273)
#    (target) "smiles awake you when you rise$"
# (generated) "I want the wall never now$"
#
# [5260] 0.5352 (k=0.0500, t=0.8890, kl=0.0411, ec=1.8535)
#    (target) "Nah nah nah nah nah nah, nah nah nah, hey Jude$"
# (generated) "I and the sky with a long$"
#
# [5280] 2.0520 (k=0.0500, t=0.8889, kl=0.0701, ec=3.1705)
#    (target) "Found my way upstairs and had a smoke$"
# (generated) "All together now$"
#
# [5300] 1.9996 (k=0.0500, t=0.8889, kl=0.0484, ec=3.1984)
#    (target) "On the way the paper bag was on my knee$"
# (generated) "All together now$"
#
# [5320] 2.0491 (k=0.0500, t=0.8888, kl=0.0555, ec=2.7402)
#    (target) "And one day his woman ran off with another guy$"
# (generated) "All together now$"
#
# [5340] 1.7672 (k=0.0500, t=0.8888, kl=0.0655, ec=3.5101)
#    (target) "And I'd have never been aware.$"
# (generated) "All together now$"
#
# [5360] 1.8568 (k=0.0500, t=0.8888, kl=0.0818, ec=2.8695)
#    (target) "And though the holes were rather small$"
# (generated) "All together now$"
#
# [5380] 1.6574 (k=0.0500, t=0.8887, kl=0.0846, ec=4.5625)
#    (target) "You feel a fool$"
# (generated) "All together now$"
#
# [5400] 1.1400 (k=0.0500, t=0.8887, kl=0.0536, ec=2.8712)
#    (target) "to get back home$"
# (generated) "All together now$"
#
# [5420] 1.3924 (k=0.0500, t=0.8886, kl=0.0812, ec=4.0748)
#    (target) "Came true today$"
# (generated) "All together now$"
#
# [5440] 2.1366 (k=0.0500, t=0.8886, kl=0.0586, ec=3.3498)
#    (target) "Only to find Gideon's Bible$"
# (generated) "All together now$"
#
# [5460] 1.7561 (k=0.0500, t=0.8886, kl=0.0596, ec=3.2434)
#    (target) "Help, not just anybody$"
# (generated) "And I want to get back to me to me$"
#
# [5480] 1.3870 (k=0.0500, t=0.8885, kl=0.0718, ec=2.6101)
#    (target) "I want to hold your hand And when I touch you$"
# (generated) "And the sun the sun the say$"
#
# [5500] 1.5840 (k=0.0500, t=0.8885, kl=0.0849, ec=2.3994)
#    (target) "Lead me to your door Oh, I need your love, babe$"
# (generated) "All together now$"
#
# Saved as vae.pt
# [5520] 1.8387 (k=0.0500, t=0.8884, kl=0.0711, ec=4.0926)
#    (target) "I am the walrus$"
# (generated) "All together now$"
#
# [5540] 2.1804 (k=0.0500, t=0.8884, kl=0.0648, ec=5.0866)
#    (target) "Somebody new$"
# (generated) "All together now$"
#
# [5560] 0.2264 (k=0.0500, t=0.8884, kl=0.1023, ec=1.3276)
#    (target) "All together now$"
# (generated) "All together now$"
#
# [5580] 2.0847 (k=0.0500, t=0.8883, kl=0.0641, ec=3.2238)
#    (target) "And proceeded to lie on the table$"
# (generated) "All together now$"
#
# [5600] 1.1920 (k=0.0500, t=0.8883, kl=0.0693, ec=2.6195)
#    (target) "All good children go to heaven$"
# (generated) "All together now$"
#
# [5620] 1.3470 (k=0.0500, t=0.8882, kl=0.0710, ec=2.6356)
#    (target) "Here comes the sun, and I say$"
# (generated) "All together now$"
#
# [5640] 1.8362 (k=0.0500, t=0.8882, kl=0.0563, ec=4.2656)
#    (target) "We're on our way home$"
# (generated) "All together now$"
#
# [5660] 1.5857 (k=0.0500, t=0.8882, kl=0.0521, ec=2.5352)
#    (target) "And all I have to do is think of her$"
# (generated) "I love you a love you$"
#
# [5680] 1.9081 (k=0.0500, t=0.8881, kl=0.0418, ec=2.3766)
#    (target) "You know I believe and how Here come old flat top$"
# (generated) "All together now$"
#
# [5700] 1.2216 (k=0.0500, t=0.8881, kl=0.0676, ec=2.4391)
#    (target) "It's all right Once there was a way,$"
# (generated) "All together now$"
#
# [5720] 1.2678 (k=0.0500, t=0.8880, kl=0.0630, ec=3.5316)
#    (target) "You can talk to me$"
# (generated) "I can't can't can the sun$"
#
# [5740] 2.1768 (k=0.0500, t=0.8880, kl=0.0919, ec=5.5380)
#    (target) "And everywhere$"
# (generated) "I can the sky with a way to me$"
#
# [5760] 1.7064 (k=0.0500, t=0.8880, kl=0.0789, ec=3.6026)
#    (target) "Will never disappear$"
# (generated) "I can the sky with day$"
#
# [5780] 1.5998 (k=0.0500, t=0.8879, kl=0.0620, ec=3.2061)
#    (target) "I'm glad it's your birthday$"
# (generated) "I can the sky with a way$"
#
# [5800] 2.8463 (k=0.0500, t=0.8879, kl=0.0786, ec=2.9180)
#    (target) "We're Sgt. Pepper's Lonely Hearts Club Band$"
# (generated) "All together now$"
#
# [5820] 1.6428 (k=0.0500, t=0.8878, kl=0.0831, ec=2.6785)
#    (target) "Look for the girl with the sun in her eyes$"
# (generated) "I'm love you see to me$"
#
# [5840] 2.3595 (k=0.0500, t=0.8878, kl=0.0481, ec=3.1205)
#    (target) "Yesterday, all my troubles seemed so far away$"
# (generated) "All together now$"
#
# [5860] 1.9505 (k=0.0500, t=0.8878, kl=0.0882, ec=3.0258)
#    (target) "You only give me your funny paper$"
# (generated) "All together now$"
#
# [5880] 0.2396 (k=0.0500, t=0.8877, kl=0.1041, ec=1.2999)
#    (target) "All together now$"
# (generated) "All together now$"
#
# [5900] 1.4433 (k=0.0500, t=0.8877, kl=0.0699, ec=4.3140)
#    (target) "Somebody new$"
# (generated) "All together now$"
#
# [5920] 0.7906 (k=0.0500, t=0.8876, kl=0.0996, ec=3.6503)
#    (target) "I love you$"
# (generated) "I love you see to me$"
#
# [5940] 1.9948 (k=0.0500, t=0.8876, kl=0.0793, ec=3.2554)
#    (target) "And then we lie, beneath a shady tree,$"
# (generated) "I can the sunshine,$"
#
# [5960] 1.1318 (k=0.0500, t=0.8876, kl=0.1077, ec=2.5970)
#    (target) "All good children go to heaven$"
# (generated) "Some to love you$"
#
# [5980] 1.1112 (k=0.0500, t=0.8875, kl=0.0711, ec=3.2965)
#    (target) "Come on and work it on out$"
# (generated) "So please you one to the sun$"
#
# [6000] 1.6370 (k=0.0500, t=0.8875, kl=0.0483, ec=2.4985)
#    (target) "Someday I'm going to make her mine Oh yeah,$"
# (generated) "In the sunshine, she say sunshine,$"
#
# Saved as vae.pt
# [6020] 2.0429 (k=0.0500, t=0.8874, kl=0.0522, ec=3.4818)
#    (target) "Lived a man who sailed to sea$"
# (generated) "And I say sunshine,$"
#
# [6040] 2.2607 (k=0.0500, t=0.8874, kl=0.1084, ec=3.1191)
#    (target) "Look at him working, darning his socks$"
# (generated) "And the sunshine,$"
#
# [6060] 2.9400 (k=0.0500, t=0.8874, kl=0.1205, ec=5.9009)
#    (target) "Michelle, ma belle$"
# (generated) "Good day sunshine,$"
#
# [6080] 2.8670 (k=0.0500, t=0.8873, kl=0.0908, ec=6.5618)
#    (target) "Dot not cry$"
# (generated) "All together now$"
#
# [6100] 2.1537 (k=0.0500, t=0.8873, kl=0.0500, ec=2.3836)
#    (target) "Can't buy me love When I get older losing my hair,$"
# (generated) "All together now$"
#
# [6120] 1.6898 (k=0.0500, t=0.8872, kl=0.0464, ec=3.0838)
#    (target) "Molly lets the children lend a hand$"
# (generated) "So please me do$"
#
# [6140] 1.4900 (k=0.0500, t=0.8872, kl=0.0752, ec=2.8723)
#    (target) "I ain't got nothing but love, babe$"
# (generated) "All together now$"
#
# [6160] 1.2934 (k=0.0500, t=0.8872, kl=0.0769, ec=3.2657)
#    (target) "I fell in love with her$"
# (generated) "All together now$"
#
# [6180] 2.1165 (k=0.0500, t=0.8871, kl=0.1050, ec=4.8374)
#    (target) "Oh I do a road hog$"
# (generated) "I don't hand her home$"
#
# [6200] 1.4904 (k=0.0500, t=0.8871, kl=0.0790, ec=3.4098)
#    (target) "Will never disappear$"
# (generated) "I can the sun his a way$"
#
# [6220] 2.1287 (k=0.0500, t=0.8870, kl=0.0696, ec=3.2107)
#    (target) "Send me a postcard, drop me a line,$"
# (generated) "All together now$"
#
# [6240] 1.8856 (k=0.0500, t=0.8870, kl=0.1183, ec=4.3954)
#    (target) "The lips I am missing$"
# (generated) "All together now$"
#
# [6260] 2.2510 (k=0.0500, t=0.8870, kl=0.0911, ec=2.9089)
#    (target) "From rocking and a-rolling spinning in a hula hoop$"
# (generated) "All together now$"
#
# [6280] 0.7570 (k=0.0500, t=0.8869, kl=0.0751, ec=2.0595)
#    (target) "Lucy in the sky with diamonds$"
# (generated) "All together now$"
#
# [6300] 2.1705 (k=0.0500, t=0.8869, kl=0.1106, ec=3.3672)
#    (target) "And then the fireman rushes in$"
# (generated) "All together now$"
#
# [6320] 1.6198 (k=0.0500, t=0.8868, kl=0.0662, ec=2.7709)
#    (target) "Making all his nowhere plans for nobody$"
# (generated) "I can't have you$"
#
# [6340] 0.9275 (k=0.0500, t=0.8868, kl=0.1078, ec=3.5473)
#    (target) "I can't hide$"
# (generated) "All together now$"
#
# [6360] 1.2487 (k=0.0500, t=0.8868, kl=0.1116, ec=3.1095)
#    (target) "I fell in love with her$"
# (generated) "I can the sky with diamond$"
#
# [6380] 2.9954 (k=0.0500, t=0.8867, kl=0.0496, ec=4.1095)
#    (target) "Protected by a silver spoon$"
# ...
#    (target) "But he knew it wouldn't last$"
# (generated) "I can't hide$"
#
# [11700] 2.0177 (k=0.0534, t=0.8761, kl=0.0548, ec=3.8547)
#    (target) "Shine until tomorrow, let it be$"
# (generated) "And I want to hold your hand$"
#
# [11720] 2.1405 (k=0.0534, t=0.8760, kl=0.1018, ec=4.8473)
#    (target) "Such a mean old man$"
# (generated) "All together now$"
#
# [11740] 1.2402 (k=0.0535, t=0.8760, kl=0.2367, ec=3.7256)
#    (target) "Jai Guru Deva$"
# (generated) "All together now$"
#
# [11760] 1.9712 (k=0.0535, t=0.8760, kl=0.0775, ec=3.8670)
#    (target) "Dripping from a dead dog's eye$"
# (generated) "Love you, love you$"
#
# [11780] 0.8796 (k=0.0536, t=0.8759, kl=0.0807, ec=3.1038)
#    (target) "You'll let me hold your hand$"
# (generated) "She loves you, love you$"
#
# [11800] 1.4658 (k=0.0536, t=0.8759, kl=0.1076, ec=3.5641)
#    (target) "'Cause I'm the taxman, yeah, I'm the taxman$"
# (generated) "I can't hide$"
#
# [11820] 1.4698 (k=0.0536, t=0.8758, kl=0.0441, ec=3.2176)
#    (target) "I only send you my invitations$"
# (generated) "I can't hide$"
#
# [11840] 1.2360 (k=0.0537, t=0.8758, kl=0.0743, ec=2.9151)
#    (target) "How do I feel by the end of the day$"
# (generated) "All together, yeah$"
#
# [11860] 0.5107 (k=0.0537, t=0.8758, kl=0.0622, ec=2.2302)
#    (target) "We're on our way home$"
# (generated) "I can't hide$"
#
# [11880] 1.9393 (k=0.0538, t=0.8757, kl=0.0561, ec=3.1707)
#    (target) "They call me on and on across the universe.$"
# (generated) "I can't hide$"
#
# [11900] 2.4769 (k=0.0538, t=0.8757, kl=0.0705, ec=5.6540)
#    (target) "Oh, that magic feeling$"
# (generated) "All together now$"
#
# [11920] 1.5694 (k=0.0538, t=0.8756, kl=0.0542, ec=3.0212)
#    (target) "I ain't got nothing but love, girl$"
# (generated) "All together now$"
#
# [11940] 1.1750 (k=0.0539, t=0.8756, kl=0.1277, ec=4.0749)
#    (target) "Let it be, let it be, let it be, let it be$"
# (generated) "All together now$"
#
# [11960] 1.5383 (k=0.0539, t=0.8756, kl=0.0253, ec=2.7365)
#    (target) "Behind the shelter in the middle of the roundabout$"
# (generated) "All together now$"
#
# [11980] 0.9811 (k=0.0540, t=0.8755, kl=0.0644, ec=3.8654)
#    (target) "Nothing is real$"
# (generated) "Well, you know it's gonna be$"
#
# [12000] 1.8300 (k=0.0540, t=0.8755, kl=0.0727, ec=4.3616)
#    (target) "I'll never do you no harm$"
# (generated) "All together now$"
#
# Saved as vae.pt
# [12020] 2.7863 (k=0.0540, t=0.8754, kl=0.0673, ec=5.9413)
#    (target) "Pornographic priestess$"
# (generated) "Well, you know it's gonna be$"
#
# [12040] 0.4606 (k=0.0541, t=0.8754, kl=0.0467, ec=1.6005)
#    (target) "Get back to where you once belonged$"
# (generated) "All together now$"
#
# [12060] 0.8718 (k=0.0541, t=0.8754, kl=0.0412, ec=2.0769)
#    (target) "carry that weight for a long time$"
# (generated) "I can t let it be, let it be, let it be, let it be"
#
# [12080] 1.0548 (k=0.0542, t=0.8753, kl=0.0399, ec=2.2845)
#    (target) "You know it's three weeks, I'm going insane$"
# (generated) "And I want to leave her now$"
#
# [12100] 2.7387 (k=0.0542, t=0.8753, kl=0.0707, ec=4.4672)
#    (target) "Climbing up the Eiffel tower$"
# (generated) "And I want to hold your hand$"
#
# [12120] 0.5510 (k=0.0542, t=0.8752, kl=0.0352, ec=1.8324)
#    (target) "We all live in a yellow submarine$"
# (generated) "All together now$"
#
# [12140] 1.6684 (k=0.0543, t=0.8752, kl=0.0504, ec=3.1583)
#    (target) "But I thought that you might like to know$"
# (generated) "You know I love you$"
#
# [12160] 0.5749 (k=0.0543, t=0.8752, kl=0.1024, ec=2.1327)
#    (target) "One, two, three, four, five, six, seven$"
# (generated) "All together now$"
#
# [12180] 1.1934 (k=0.0544, t=0.8751, kl=0.0392, ec=2.9277)
#    (target) "Knowing that love is to share$"
# (generated) "I can't hide and work it on our way$"
#
# [12200] 2.6376 (k=0.0544, t=0.8751, kl=0.0506, ec=3.7103)
#    (target) "Four thousand holes in Blackburn, Lancashire$"
# (generated) "And I will sing a long time$"
#
# [12220] 1.4935 (k=0.0544, t=0.8750, kl=0.0510, ec=3.0808)
#    (target) "That she keeps in a jar by the door$"
# (generated) "All together now$"
#
# [12240] 0.8029 (k=0.0545, t=0.8750, kl=0.1289, ec=2.9052)
#    (target) "Come on, come on, come, come on baby now$"
# (generated) "They are the life the sun$"
#
# [12260] 0.8451 (k=0.0545, t=0.8750, kl=0.1132, ec=2.3792)
#    (target) "Someone like you Love, love me do$"
# (generated) "All together now$"
#
# [12280] 0.4698 (k=0.0546, t=0.8749, kl=0.0957, ec=2.1084)
#    (target) "Good day sunshine.$"
# (generated) "They are the eyes$"
#
# [12300] 0.9949 (k=0.0546, t=0.8749, kl=0.0561, ec=2.5706)
#    (target) "For the things you do endear you to me$"
# (generated) "I can't hide$"
#
# [12320] 1.5321 (k=0.0546, t=0.8748, kl=0.0790, ec=3.9565)
#    (target) "Skip the rope bompa bom$"
# (generated) "All together now$"
#
# [12340] 2.0567 (k=0.0547, t=0.8748, kl=0.0481, ec=3.4403)
#    (target) "And looking up I noticed I was late$"
# (generated) "They are the sun$"
#
# [12360] 1.5291 (k=0.0547, t=0.8748, kl=0.0582, ec=3.1544)
#    (target) "You know I'd give you everything I've got$"
# (generated) "All together now$"
#
# [12380] 1.2791 (k=0.0548, t=0.8747, kl=0.0258, ec=3.0441)
#    (target) "And when I ask you to be mine,$"
# (generated) "All together now$"
#
# [12400] 1.6490 (k=0.0548, t=0.8747, kl=0.0324, ec=3.5312)
#    (target) "is equal to the love you make,$"
# (generated) "I can't hide$"
#
# [12420] 0.8028 (k=0.0548, t=0.8746, kl=0.0481, ec=2.4889)
#    (target) "Back to where you once belonged$"
# (generated) "And I will sing and should here it comes$"
#
# [12440] 1.9630 (k=0.0549, t=0.8746, kl=0.0648, ec=3.6567)
#    (target) "And we held each other tight$"
# (generated) "And I will sing a lullaby too door$"
#
# [12460] 2.5417 (k=0.0549, t=0.8746, kl=0.0712, ec=5.1959)
#    (target) "Teacher gets annoyed.$"
# (generated) "Sun, sun, sun, sun, sun, sun, sun, sun, sun, sun, "
#
# [12480] 0.6909 (k=0.0550, t=0.8745, kl=0.2291, ec=2.6370)
#    (target) "Jai Guru Deva$"
# (generated) "All together now$"
#
# [12500] 0.9728 (k=0.0550, t=0.8745, kl=0.0806, ec=2.4243)
#    (target) "You say "Goodbye" and I say "Hello, hello, hello".$"
# (generated) "She loves you, yeah, yeah, yeah, yeah, yeah, yeah,"
#
# Saved as vae.pt
# [12520] 1.1220 (k=0.0550, t=0.8744, kl=0.1820, ec=4.2977)
#    (target) "Goo goo goo g' joob$"
# (generated) "Some only waiting to me$"
#
# [12540] 2.2373 (k=0.0551, t=0.8744, kl=0.0392, ec=3.6325)
#    (target) "Now it looks as though they're here to stay$"
# (generated) "All together now$"
#
# [12560] 2.6966 (k=0.0551, t=0.8744, kl=0.1051, ec=5.1451)
#    (target) "Pools of sorrow waves of joy$"
# (generated) "All together now$"
#
# [12580] 1.7070 (k=0.0552, t=0.8743, kl=0.0489, ec=3.2324)
#    (target) "Take these broken wings and learn to fly$"
# (generated) "All together now$"
#
# [12600] 1.9483 (k=0.0552, t=0.8743, kl=0.0555, ec=3.1431)
#    (target) "We're going home Two of us sending postcards$"
# (generated) "All together now$"
#
# [12620] 0.5516 (k=0.0552, t=0.8742, kl=0.0338, ec=1.5011)
#    (target) "'Cause I'm going to Strawberry Fields$"
# (generated) "All together now$"
#
# [12640] 0.5377 (k=0.0553, t=0.8742, kl=0.1072, ec=3.0996)
#    (target) "Yeah, yeah, yeah,$"
# (generated) "All together now$"
#
# [12660] 0.8358 (k=0.0553, t=0.8742, kl=0.0497, ec=3.1723)
#    (target) "And the eyes in his head$"
# (generated) "All together now$"
#
# [12680] 1.3181 (k=0.0554, t=0.8741, kl=0.0640, ec=2.8385)
#    (target) "Come on and twist a little closer now$"
# (generated) "All together now$"
#
# [12700] 1.9473 (k=0.0554, t=0.8741, kl=0.0450, ec=3.9515)
#    (target) "Protected by a silver spoon$"
# (generated) "All together now$"
#
# [12720] 1.2872 (k=0.0554, t=0.8740, kl=0.0757, ec=3.5365)
#    (target) "Can I have a little more$"
# (generated) "All together now$"
#
# [12740] 1.2938 (k=0.0555, t=0.8740, kl=0.0533, ec=3.1991)
#    (target) "Sleeps in a hole in the road$"
# (generated) "All together now$"
#
# [12760] 1.4696 (k=0.0555, t=0.8740, kl=0.0402, ec=3.1708)
#    (target) "And was buried along with her name$"
# (generated) "I can't hide$"
#
# [12780] 0.9981 (k=0.0556, t=0.8739, kl=0.0952, ec=3.0399)
#    (target) "Come on, come on, come, come on baby now$"
# (generated) "All together now$"
#
# [12800] 1.6200 (k=0.0556, t=0.8739, kl=0.1047, ec=4.7508)
#    (target) "Look around round round$"
# (generated) "And I will always be true$"
#
# [12820] 0.8589 (k=0.0556, t=0.8738, kl=0.0794, ec=3.9013)
#    (target) "And everywhere$"
# (generated) "And I wall sing a little help and shout$"
#
# [12840] 0.4957 (k=0.0557, t=0.8738, kl=0.0406, ec=1.8562)
#    (target) "Back to where you once belonged$"
# (generated) "All together now$"
#
# [12860] 1.3373 (k=0.0557, t=0.8738, kl=0.0428, ec=3.0599)
#    (target) "No one there to tell us what to do$"
# (generated) "Will never die$"
#
# [12880] 1.4193 (k=0.0558, t=0.8737, kl=0.0409, ec=3.1995)
#    (target) "Nobody can deny that there's something there$"
# (generated) "All together now$"
#
# [12900] 0.7444 (k=0.0558, t=0.8737, kl=0.0398, ec=2.4373)
#    (target) "This could only happen to me$"
# (generated) "All together now$"
#
# [12920] 1.5128 (k=0.0558, t=0.8736, kl=0.0722, ec=3.7226)
#    (target) "The wind is low the birds will sing$"
# (generated) "All together now$"
#
# [12940] 1.3204 (k=0.0559, t=0.8736, kl=0.0424, ec=2.7038)
#    (target) "I would like you to dance--Birthday$"
# (generated) "All together now$"
#
# [12960] 0.5360 (k=0.0559, t=0.8736, kl=0.0671, ec=2.6652)
#    (target) "You know I love you$"
# (generated) "All together now$"
#
# [12980] 1.8591 (k=0.0560, t=0.8735, kl=0.0461, ec=4.2484)
#    (target) "Found my coat and grabbed my hat$"
# (generated) "I can't hide$"
#
# [13000] 1.8840 (k=0.0560, t=0.8735, kl=0.0494, ec=4.0407)
#    (target) "And the banker never wears a mac$"
# (generated) "I can't hide$"
#
# Saved as vae.pt
# [13020] 1.3301 (k=0.0560, t=0.8734, kl=0.0551, ec=3.2407)
#    (target) "I'm glad it's your birthday$"
# (generated) "All together now$"
#
# [13040] 1.1308 (k=0.0561, t=0.8734, kl=0.0692, ec=2.7248)
#    (target) "Don't you know that you can count me out$"
# (generated) "All together now$"
#
# [13060] 0.3495 (k=0.0561, t=0.8734, kl=0.0713, ec=1.6302)
#    (target) "Good day sunshine,$"
# (generated) "I want to hold your hand$"
#
# [13080] 2.2170 (k=0.0562, t=0.8733, kl=0.0697, ec=4.4083)
#    (target) "La la how the life goes on$"
# (generated) "All together now$"
#
# [13100] 0.3567 (k=0.0562, t=0.8733, kl=0.0585, ec=1.3883)
#    (target) "One, two, three, four, five, six, seven$"
# (generated) "You know I love you$"
#
# [13120] 1.2775 (k=0.0562, t=0.8732, kl=0.0506, ec=3.2183)
#    (target) "I only send you my invitations$"
# (generated) "All together now$"
#
# [13140] 0.6491 (k=0.0563, t=0.8732, kl=0.0537, ec=3.0683)
#    (target) "Will never die$"
# (generated) "All together now$"
#
# [13160] 0.3139 (k=0.0563, t=0.8732, kl=0.0755, ec=1.4288)
#    (target) "All good children go to heaven$"
# (generated) "All together now$"
#
# [13180] 1.7436 (k=0.0564, t=0.8731, kl=0.0825, ec=4.8806)
#    (target) "I feel the wind blow$"
# (generated) "All together now$"
#
# [13200] 1.5248 (k=0.0564, t=0.8731, kl=0.0361, ec=3.2707)
#    (target) "That she keeps in a jar by the door$"
# (generated) "All together now$"
#
# [13220] 1.6269 (k=0.0564, t=0.8730, kl=0.0414, ec=3.7260)
#    (target) "They tell me in sweet fragrant meadows$"
# (generated) "I want to hold your hand$"
#
# [13240] 0.3949 (k=0.0565, t=0.8730, kl=0.0961, ec=2.8126)
#    (target) "Yeah, yeah, yeah$"
# (generated) "All together now$"
#
# [13260] 1.4659 (k=0.0565, t=0.8730, kl=0.0331, ec=3.2925)
#    (target) "Each one believing that love never dies$"
# (generated) "I want to hold your hand$"
#
# [13280] 1.4079 (k=0.0566, t=0.8729, kl=0.0579, ec=3.6514)
#    (target) "Sitting in his nowhere land$"
# (generated) "All together now$"
#
# [13300] 1.4478 (k=0.0566, t=0.8729, kl=0.0486, ec=3.4706)
#    (target) "There, running my hands through her hair$"
# (generated) "All together now$"
#
# [13320] 2.0460 (k=0.0566, t=0.8728, kl=0.0405, ec=2.9537)
#    (target) "Now junior, behave yourself I give her all my love$"
# (generated) "I think you should be gonna change my world$"
#
# [13340] 1.7921 (k=0.0567, t=0.8728, kl=0.0339, ec=3.0062)
#    (target) "For some California grass Get back, get back$"
# (generated) "All together now$"
#
# [13360] 0.1836 (k=0.0567, t=0.8728, kl=0.1053, ec=1.1358)
#    (target) "All together now$"
# (generated) "All together now$"
#
# [13380] 0.2995 (k=0.0568, t=0.8727, kl=0.0464, ec=1.2446)
#    (target) "Get back to where you once belonged$"
# (generated) "All together now$"
#
# [13400] 0.5160 (k=0.0568, t=0.8727, kl=0.0907, ec=2.0305)
#    (target) "Eight days a week$"
# (generated) "All together now$"
#
# [13420] 1.6363 (k=0.0568, t=0.8726, kl=0.0372, ec=3.3820)
#    (target) "You were made to go out and get her$"
# (generated) "All together now$"
#
# [13440] 1.9164 (k=0.0569, t=0.8726, kl=0.0439, ec=3.6199)
#    (target) "She never stops; she's a go-getter$"
# (generated) "All together now$"
#
# [13460] 0.8719 (k=0.0569, t=0.8726, kl=0.0352, ec=2.1892)
#    (target) "You know I feel alright... Love, love me do$"
# (generated) "I can't hide and she keeps calling$"
#
# [13480] 2.5436 (k=0.0570, t=0.8725, kl=0.0788, ec=4.8196)
#    (target) "Hold you in his armchair$"
# (generated) "All together now$"
#
# [13500] 1.8640 (k=0.0570, t=0.8725, kl=0.0657, ec=5.0082)
#    (target) "You're meant to be$"
# (generated) "All together now$"
#
# Saved as vae.pt
# [13520] 1.9462 (k=0.0570, t=0.8724, kl=0.0607, ec=3.2556)
#    (target) "What do you see when you turn out the light?$"
# (generated) "You know I love you$"
#
# [13540] 1.7521 (k=0.0571, t=0.8724, kl=0.0572, ec=4.6194)
#    (target) "A long long time ago$"
# (generated) "All together now$"
#
# [13560] 2.1979 (k=0.0571, t=0.8724, kl=0.0313, ec=4.4106)
#    (target) "Tuesday's on the phone to me$"
# (generated) "All together now$"
#
# [13580] 0.2336 (k=0.0572, t=0.8723, kl=0.1103, ec=1.5770)
#    (target) "All together now$"
# (generated) "All together now$"
#
# [13600] 1.7343 (k=0.0572, t=0.8723, kl=0.0359, ec=4.0471)
#    (target) "Then you'll begin to make it$"
# (generated) "You know I love you$"
#
# [13620] 1.0008 (k=0.0572, t=0.8722, kl=0.0324, ec=2.5242)
#    (target) "And in the middle of the celebrations,$"
# (generated) "All together now$"
#
# [13640] 1.6088 (k=0.0573, t=0.8722, kl=0.0414, ec=2.7731)
#    (target) "If you want me to, I will And if I ever saw you$"
# (generated) "All together now$"
#
# [13660] 0.5153 (k=0.0573, t=0.8722, kl=0.0758, ec=3.0929)
#    (target) "Well, you know$"
# (generated) "All together now$"
#
# [13680] 0.7220 (k=0.0574, t=0.8721, kl=0.1008, ec=3.0200)
#    (target) "Love you, love you$"
# (generated) "All together now$"
#
# [13700] 2.1227 (k=0.0574, t=0.8721, kl=0.0609, ec=4.1266)
#    (target) "Late nights all alone with a test tube.$"
# (generated) "I want to hold your hand$"
#
# [13720] 0.4702 (k=0.0574, t=0.8720, kl=0.0988, ec=2.6090)
#    (target) "Get back, get back$"
# (generated) "All together now$"
#
# [13740] 1.9904 (k=0.0575, t=0.8720, kl=0.0362, ec=3.3736)
#    (target) "And one day his woman ran off with another guy$"
# (generated) "All together now$"
#
# [13760] 0.2171 (k=0.0575, t=0.8720, kl=0.0312, ec=1.1654)
#    (target) "All good children go to heaven$"
# (generated) "All together now$"
#
# [13780] 1.5426 (k=0.0576, t=0.8719, kl=0.0440, ec=2.9521)
#    (target) "Somebody calls you, you answer quite slowly$"
# (generated) "All good children go to heaven$"
#
# [13800] 1.4168 (k=0.0576, t=0.8719, kl=0.0395, ec=4.5841)
#    (target) "And now she says she knows$"
# (generated) "All together now$"
#
# [13820] 0.7089 (k=0.0576, t=0.8718, kl=0.0659, ec=2.0745)
#    (target) "Don't you know it's gonna last$"
# (generated) "All good children go to heaven$"
#
# [13840] 0.5460 (k=0.0577, t=0.8718, kl=0.0451, ec=2.2160)
#    (target) "Yellow submarine, yellow submarine$"
# (generated) "And I want to hold your hand$"
#
# [13860] 0.3156 (k=0.0577, t=0.8718, kl=0.0740, ec=1.5657)
#    (target) "Good day sunshine,$"
# (generated) "All together now$"
#
# [13880] 1.3799 (k=0.0578, t=0.8717, kl=0.0328, ec=3.0379)
#    (target) "And Moscow girls make me sing and shout$"
# (generated) "All together now$"
#
# [13900] 2.1919 (k=0.0578, t=0.8717, kl=0.1558, ec=6.2681)
#    (target) "Drinking her wine$"
# (generated) "All together now$"
#
# [13920] 1.4161 (k=0.0578, t=0.8716, kl=0.0698, ec=3.4640)
#    (target) "In summer. Meanwhile back$"
# (generated) "I want to hold your hand$"
